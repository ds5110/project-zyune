# %%
import pandas as pd
import geopandas as gpd

# %%
ls
# Out:
# Cumberland/                           divide tier4 data into zipcdoe.ipynb
# Cumberland_zip/                       explore zipcode data.ipynb
# Penobscot_zip/                        try to build the model.ipynb

# %%
B16010_041E=gpd.read_file('/Users/yune/project-zyune/county/Cumberland/CumberlandB16010_041E.geojson')
B19019_001E=gpd.read_file('/Users/yune/project-zyune/county/Cumberland/CumberlandB19019_001E.geojson')
B28003_004E=gpd.read_file('/Users/yune/project-zyune/county/Cumberland/CumberlandB28003_004E.geojson')
B01001_001E=gpd.read_file('/Users/yune/project-zyune/county/Cumberland/CumberlandB01001_001E.geojson')

# %%
df = pd.DataFrame()
df['ZCTA5CE10']=B01001_001E['ZCTA5CE10']
df['total_population']=B01001_001E['B01001_001E']
df['num_of_bachelor_degree_higer']=B16010_041E['B16010_041E']
df['num_of_internet_subscribe']=B28003_004E['B28003_004E']
df['median_household_income']=B19019_001E['B19019_001E']
# B28006_014E

# %%
def find_number_of_tiers_according_to_zipcode(county_name,zipcode,tier_num):
    try:
        directory=county_name+'_zip/'+tier_num+'/'+zipcode+'.geojson'
        print(directory)
        gdf=gpd.read_file(directory)
        return len(gdf)
    except:
        return 0

find_number_of_tiers_according_to_zipcode('Cumberland','04101','tier_4')
# Out:
# Cumberland_zip/tier_4/04101.geojson
# 775

# %%
tier_list=['tier_0','tier_1','tier_2','tier_3','tier_4','tier_5']
for tiers in tier_list:
    tier_list=[]
    for zipcode in df['ZCTA5CE10']:
        
        tier_list.append(find_number_of_tiers_according_to_zipcode('Cumberland','0'+str(zipcode),tiers))
    new_column_name='num_'+tiers
    df[new_column_name]=pd.DataFrame(tier_list)
# Out:
# Cumberland_zip/tier_0/04003.geojson
# Cumberland_zip/tier_0/04009.geojson
# Cumberland_zip/tier_0/04011.geojson
# Cumberland_zip/tier_0/04015.geojson
# Cumberland_zip/tier_0/04017.geojson
# Cumberland_zip/tier_0/04019.geojson
# Cumberland_zip/tier_0/04021.geojson
# Cumberland_zip/tier_0/04024.geojson
# Cumberland_zip/tier_0/04029.geojson
# Cumberland_zip/tier_0/04032.geojson
# Cumberland_zip/tier_0/04038.geojson
# Cumberland_zip/tier_0/04039.geojson
# Cumberland_zip/tier_0/04040.geojson
# Cumberland_zip/tier_0/04050.geojson
# Cumberland_zip/tier_0/04055.geojson
# Cumberland_zip/tier_0/04057.geojson
# Cumberland_zip/tier_0/04062.geojson
# Cumberland_zip/tier_0/04066.geojson
# Cumberland_zip/tier_0/04069.geojson
# Cumberland_zip/tier_0/04071.geojson
# Cumberland_zip/tier_0/04074.geojson
# Cumberland_zip/tier_0/04079.geojson
# Cumberland_zip/tier_0/04084.geojson
# Cumberland_zip/tier_0/04085.geojson
# Cumberland_zip/tier_0/04091.geojson
# Cumberland_zip/tier_0/04092.geojson
# ...

# %%
df['geometry']=B01001_001E['geometry']
df
# Out:
#     ZCTA5CE10  total_population  num_of_bachelor_degree_higer  \
# 0        4003               214                            80
# 1        4009              5335                          1356
# 2        4011             20565                          6827
# 3        4015              3838                           941
# 4        4017               515                           200
# 5        4019                42                            33
# 6        4021              6612                          2857
# 7        4024               580                            47
# 8        4029              1830                           326
# 9        4032              8517                          3432
# 10       4038             17723                          4744
# 11       4039              7596                          2529
# 12       4040              3348                           651
# 13       4050               282                           117
# ...

# %%
df.to_csv('number_of_tiers_cumberlamd_zipcode.csv',index=False)
